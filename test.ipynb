# %%
import torch
print("CUDA 可用:", torch.cuda.is_available())
print("你的显卡:", torch.cuda.get_device_name(0))
print("PyTorch 版本:", torch.__version__)

# 跑一个极小的矩阵乘法，感受一下 5060Ti 的呼吸
x = torch.randn(1000, 1000).cuda()
y = torch.randn(1000, 1000).cuda()
z = x @ y
print("张量运算成功，结果形状:", z.shape)
# Out:
# CUDA 可用: True
# 你的显卡: NVIDIA GeForce RTX 5060 Ti
# PyTorch 版本: 2.12.1+cu130
# 张量运算成功，结果形状: torch.Size([1000, 1000])

# %%
# !nvidia-smi
# Out:
# Sun Jun 21 20:59:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.71.05              Driver Version: 595.71.05      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060 Ti     Off |   00000000:01:00.0  On |                  N/A |
# |  0%   32C    P1             17W /  180W |    3399MiB /  16311MiB |      4%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
x = torch.randn(4096, 4096).cuda(); 
y = x @ x
# !表示后面输入的为shell系统命令
# !nvidia-smi
# Out:
# Sun Jun 21 21:10:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.71.05              Driver Version: 595.71.05      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060 Ti     Off |   00000000:01:00.0  On |                  N/A |
# |  0%   31C    P3             14W /  180W |    3361MiB /  16311MiB |      4%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
from torch import nn
class MLP(nn.Module):
    # 声明带有模型参数的层，这⾥里里声明了了两个全连接层
    def __init__(self, **kwargs):
        # 调⽤用MLP⽗父类Block的构造函数来进⾏行行必要的初始化。这样在构造实例例时还可以指定其他函数
        # 参数，如“模型参数的访问、初始化和共享”⼀一节将介绍的模型参数params
        super(MLP, self).__init__(**kwargs)
        self.hidden = nn.Linear(784, 256) # 隐藏层
        self.act = nn.ReLU()
        self.output = nn.Linear(256, 10) # 输出层
    # 定义模型的前向计算，即如何根据输⼊入x计算返回所需要的模型输出
    def forward(self, x):
        a = self.act(self.hidden(x))
        return self.output(a)
X = torch.rand(2, 784)
net = MLP()
print(net)
net(X)

# !nvidia-smi
# Out:
# MLP(
#   (hidden): Linear(in_features=784, out_features=256, bias=True)
#   (act): ReLU()
#   (output): Linear(in_features=256, out_features=10, bias=True)
# )
# Sun Jun 21 21:18:56 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.71.05              Driver Version: 595.71.05      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060 Ti     Off |   00000000:01:00.0  On |                  N/A |
# ...
